# %%
# 1. Write a program to find the minimum price of ktm bike, 
# which are available in Jaipur, and how many ktm bikes are 
# available at Jaipur location.

# %%
import pandas as pd

# %%
df = pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
a = df[(df['brand']=="KTM")& (df['city']=="Jaipur")]
a
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
df[(df['brand']=="KTM")& (df['city']=="Jaipur")&(df['price']<=130000)]
# Out:
#          bike_name     price    city  kms_driven        owner  age  power  \
# 6734  KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
#
#      brand
# 6734   KTM

# %%
a['price'].min()
# Out:
# 128000.0

# %%
a.shape       # 8 ktm bikes available in jaipur
# Out:
# (8, 8)

# %%
# 2. Find out how many bikes are available at Delhi location, and 
# that are “first owner” bikes. And also after filter the data 
# find out the minimum and maximum age of the bike.

# %%
df[(df['city']=="Delhi")]
# Out:
#                                  bike_name     price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 32639          Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32640               Hero Passion Pro 100cc   32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc   41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc   39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220   60000.0  Delhi     20373.0
#
#               owner   age  power          brand
# 1       First Owner   4.0  350.0  Royal Enfield
# ...

# %%
df[(df['city']=="Delhi")].shape
# Out:
# (7318, 8)

# %%
df[(df['city']=="Delhi")&(df['owner']=="First Owner")].shape
#6516 bikes are available in Delhi which are first hand Owner
# Out:
# (6516, 8)

# %%
df[(df['city']=="Delhi")&(df['age']<=1)]
# Out:
#              bike_name    price   city  kms_driven        owner  age  power  \
# 7235  Honda Livo 110cc  60000.0  Delhi        74.0  First Owner  1.0  110.0
#
#       brand
# 7235  Honda

# %%
a['age'].min()
# Out:
# 1.0

# %%
a['age'].max()
# Out:
# 63.0

# %%
# 3. Try to read excel data using pandas. You can take any excel file for this assignment. 
# If you will face any error in this question, you can take reference from internet.

# %%
import pandas as pd
df = pd.read_csv("employees.csv")
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[(df['Gender'] == "Male")].shape
# Out:
# (424, 8)

# %%
df[(df['Team'] == "Finance")]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 46       Bruce    Male  11/28/2009        10:47 PM  114796    6.796
# ..         ...     ...         ...             ...     ...      ...
# 907  Elizabeth  Female   7/27/1998        11:12 AM  137144   10.081
# 954        Joe    Male   1/19/1980         4:06 PM  119667    1.148
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                 NaN  Finance
# ...

# %%
df[(df['Team'] == "Finance")].shape
# Out:
# (102, 8)

# %%
df[(df['Senior Management'] == True)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# ..         ...     ...         ...             ...     ...      ...
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# ...

# %%
df[(df['Senior Management'] == True)].shape
# Out:
# (468, 8)

# %%
df[(df['Salary'] >= 125000)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 18       Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 23         NaN    Male   6/14/2012         4:19 PM  125792    5.042
# ..         ...     ...         ...             ...     ...      ...
# 983       John    Male  12/23/1982        10:35 PM  146907   11.738
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# ...
